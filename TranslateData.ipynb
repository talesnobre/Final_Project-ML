# %%
import pandas as pd

# %%
df = pd.read_csv("twitter_st.csv")
df
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# ...

# %%
# %pip install mtranslate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3671 sha256=a066268890803dd77304615fb1b5a6bd34d63413340b51fd756873c14ed83b93
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# ...

# %%
from tqdm import tqdm
from mtranslate import translate

translated_tweets = []

for tweet in tqdm(df['tweet']):
    translated_tweet = translate(tweet, 'pt', 'en')
    translated_tweets.append(translated_tweet)

df['tweets_pt'] = translated_tweets
df.to_csv('Dados/twitter_trad.csv', index=False)
# Out:
# 100%|██████████| 24783/24783 [1:30:27<00:00,  4.57it/s]

# %%
df
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet  \
# ...

# %%
# from google.colab import drive

# drive.mount('/content/drive')
# df.to_csv('/content/drive/My Drive/AIpp/games.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
