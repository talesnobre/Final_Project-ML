# %%
import pandas as pd

# %%
df = pd.read_csv('Dados/twitter.csv')
df
# Out:
#        count  hate_speech  offensive_language  neither  class  \
# 0          3            0                   0        3      2
# 1          3            0                   3        0      1
# 2          3            0                   3        0      1
# 3          3            0                   2        1      1
# 4          6            0                   6        0      1
# ...      ...          ...                 ...      ...    ...
# 24778      3            0                   2        1      1
# 24779      3            0                   1        2      2
# 24780      3            0                   3        0      1
# 24781      6            0                   6        0      1
# 24782      3            0                   0        3      2
#
#                                                tweets_en  \
# 0        mayasolovely   woman shouldnt complain clean...
# 1         boy dats coldtyga dwn bad cuffin dat hoe   ...
# ...
